# %% [markdown]
# # Introdução à Estatística para Ciência de Dados

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Parte 1 - Estatística Descritiva: Conceitos Básicos, Tipos de Variáveis e Gráficos

# %% [markdown]
# * Variáveis e tipos de variáveis:
#
# Variável	é	qualquer	característica	associada	a	uma	população. Podem	ser	classificadas	em:
#
# * **Variáveis	qualitativas:**	representam	atributos,	qualidades,	que
#  podem	ser	divididas	em	dois	grupos,	ordinais	(quando	existir	uma
#  ordem	implícita)	e	nominais	(quando	não	existir	uma	ordem
#  implícita).	Exemplos:
#
#    - **Variáveis	qualitativas	ordinais:**	classe	social,	grau	de
#  instrução	e	estágio	da	doença.
#
#    - **Variáveis	qualitativas	nominais:**	sexo,	cor	dos	olhos,
#  fumante/não	fumante	e	doente/sadio.
#
# * **Variáveis	quantitativas:**	podem	ser	divididas	em	dois	grupos,
#  discretas	(quando	for	finita	e	enumerável)	e	contínuas	(quando	os
#  resultados	possíveis	pertencerem	a	um	intervalo	de	números	reais
#  e	resultados	de	mensuração).	Exemplos:
#
#    - **Variáveis	quantitativas	discretas:**	número	de	filhos,
#  número	de	carros	e	número	de	cigarros	fumados	por	dia.
#    - **Variáveis	quantitativas	contínuas:**	peso,	altura	e	salário.

# %% [markdown]
# A	figura	a	seguir	resume	os	tipos	de	variáveis:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * Gráficos para variáveis qualitativas

# %%
# Gráfico de setores ou pizza

# imports de bibliotecas
from matplotlib import pyplot
# categorias e tamanho dos setores. Os setores serão ordenados e plotados no sentido anti-horário
categorias = 'Java','R','Python'
setores = [45,25,30]
# criação do gráfico
pyplot.pie(x=setores,labels=categorias,autopct='%.1f%%')
pyplot.show()

# %%
# Gráfico de colunas (vertica)

# imports de bibliotecas
from matplotlib import pyplot
# categorias
x = ['R','Java','Python']
# valores de cada categoria
y = [27,42,89]
# criação do gráfico
grafico = pyplot.bar(x,y,color='black')
# exibindo o rótulo
pyplot.bar_label(grafico)
pyplot.xlabel('Eixo x')
pyplot.ylabel('Eixo y')
pyplot.title('Título do Gráfico')
# exibição do gráfico
pyplot.show()

# %%
# Gráfico de barras (horizontal)

# imports de bibliotecas
from matplotlib import pyplot
# categorias
x = ['R','Java','Python']
# valores de cada categoria
y = [27,42,89]
# criação do gráfico
grafico = pyplot.barh(x,y,color='green')
# exibindo o rótulo
pyplot.bar_label(grafico)
pyplot.xlabel('Eixo x')
pyplot.ylabel('Eixo y')
pyplot.title('Título do Gráfico')
# exibição do gráfico
pyplot.show()

# %% [markdown]
# * Gráficos para variáveis quantitativas

# %%
# Gráfico de dispersão

# imports de bibliotecas
from matplotlib import pyplot
# valores de x
idade = [20, 35, 45, 25, 60, 30, 50, 40]
# valores de y
horas_sono = [8.5, 7.2, 6.5, 8.0, 6.0, 7.8, 6.8, 7.0]
# criação do gráfico
pyplot.scatter(idade,horas_sono,color='black')
# Adicionando rótulos
pyplot.title('Relação entre Idade e Horas de Sono')
pyplot.xlabel('Idade (Anos)')
pyplot.ylabel('Horas de Sono por Noite')
# exibição do gráfico
pyplot.show()

# %%
# Gráfico de Histograma

# imports de bibliotecas
from matplotlib import pyplot
# valores
x = [64,77,45,64,88,11,22,67,81,88,43,51,18,32,3,10,
     90,20,24,63,51,96,11,78]
# número de intervalos (bins = 6)
# criação do gráfico
grafico = pyplot.hist(x, bins=6, color='red', edgecolor='blue', alpha=0.7)
# Adicionando rótulos
pyplot.title('Relação entre Idade e Horas de Sono')
pyplot.xlabel('Idade (Anos)')
pyplot.ylabel('Horas de Sono por Noite')
# exibição do gráfico
pyplot.show()

# Observação:
# bins=quantidade de barras igualmente intervaladas
# color=cor principal
# edgecolor=cor de contorno da barra
# alpha= transparência da cor principal (0.0 a 1.0)

# %%
# Gráfico de Linhas

# imports de bibliotecas
from matplotlib import pyplot
# valores de x
x =	[3,10,11,13,18,20,22,24,32,43,45,51,56,63,64,67,
     69,77,78,81,83,88,90,96]
# Valores de y
y =	[2,2,9,1,6,6,0,6,9,1,8,4,1,9,7,3,5,4,1,6,0,2,5,7]
# criação do gráfico
pyplot.plot(x,y,'green',alpha=0.6)
# Adicionando rótulos
pyplot.title('Gráfico Temporal')
pyplot.xlabel('Eixo x')
pyplot.ylabel('Eixo y')
# exibição do gráfico
pyplot.show()

# %% [markdown]
# * CORRELAÇÃO
#
#     A **correlação** é uma medida estatística que descreve o grau de relacionamento linear entre duas variáveis. Ela indica se, e como, as duas variáveis se movem juntas. Quando duas variáveis estão correlacionadas, o comportamento de uma delas está relacionado ao comportamento da outra, de alguma forma. A correlação é usada em Ciência de Dados principalmente para:
#
#     * **Entender relações entre variáveis:** ela permite aos cientistas de dados identificar se existe uma relação entre duas variáveis e como essa relação se manifesta. Por exemplo, em um conjunto de dados de vendas de um produto, a correlação pode ajudar a determinar se a publicidade gasta em marketing afeta as vendas do produto.
#
#     * **Seleção de características:** em tarefas de modelagem preditiva, a correlação pode ser usada para selecionar as variáveis mais relevantes. Variáveis altamente correlacionadas podem fornecer informações semelhantes, o que pode levar à redundância nos modelos. Portanto, pode ser desejável manter apenas uma das variáveis altamente correlacionadas.
#
#     * **Validação de modelos:** a correlação pode ser usada para avaliar o desempenho de modelos preditivos. Comparar a correlação entre as previsões do modelo e os valores reais ajuda a determinar o quão bem o modelo está se ajustando aos dados.
#
#     * **Detecção de multicolinearidade:** em regressões múltiplas, a correlação entre as variáveis independentes é usada para detectar multicolinearidade. Isso ocorre quando duas ou mais variáveis independentes estão altamente correlacionadas, o que pode prejudicar a precisão das estimativas do modelo.
#
#     * **Análise exploratória de dados:** a correlação é uma ferramenta útil na análise exploratória de dados para identificar relações potenciais que podem orientar análises subsequentes.
#
#     Existem várias formas de calcular a correlação, sendo a **Correlação de Pearson** e a **Correlação de Spearman** as mais comuns.
#
#     * **Correlação de Pearson:** mede a relação linear entre duas variáveis contínuas. Varia de -1 (correlação negativa perfeita) a 1 (correlação positiva perfeita), com 0 indicando nenhuma correlação linear.
#
#     * **Correlação de Spearman:** também conhecida como Correlação de Classificação, avalia a relação monotônica entre duas variáveis, independentemente de ser linear. É útil quando as variáveis não têm distribuições normais. Este método é baseado na classificação dos valores coletados e não nos próprios valores, podendo ser usado para variáveis em escalas ordinais.
#
# É importante notar que **correlação não implica causalidade**. Ou seja, apenas porque duas variáveis estão correlacionadas, não significa que uma causa a outra. Outros fatores podem estar envolvidos, e a causalidade geralmente requer evidências adicionais além da correlação. Em resumo, a correlação é uma ferramenta valiosa em Ciência de Dados para entender relações entre variáveis, validar modelos e auxiliar na tomada de decisões com base em dados.
#
# Quanto mais próximo o valor da Correlação de Pearson estiver de 1, mais forte será a correlação positiva entre as variáveis, e quanto mais próximo de -1, mais forte será a correlação negativa. Um valor próximo de 0 indica uma correlação fraca ou ausência de correlação linear.

# %%
# Correlação de Pearson em Python
import numpy as np

# dados de exemplo (duas variáveis)
renda_mensal = [3000,4500,6000,7500,9000,10500,12000]
gastos_lazer = [250,380,500,650,780,850,1000]

# calculando a correlação de Pearson
correlação = np.corrcoef(renda_mensal,gastos_lazer)[0,1]
print(f"Correlação de Pearson: {correlação}")

# Observação:
# O índice [0, 1] é usado para extrair o valor
# do coeficiente de correlação de Pearson entre as duas variáveis
# (renda_mensal e gastos_lazer) da matriz que é retornada pela
# função np.corrcoef().
# Out:
# Correlação de Pearson: 0.9977197878824873

# %%
# Correlação de Pearson em Pandas e Matplotlib

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# criando um dataframe de exemplo com algumas variáveis
dados = {
    'Idade':[45,20,25,40,34],
    'Salário':[10_000,70_000,5_000,9_000,8_000],
    'experiência':[13,2,5,10,12]
}

df = pd.DataFrame(dados)

# calculando a matriz de correlação
matriz_correlacao = df.corr()

# plotando a matriz de correlação como um gráfico de calor com valores
plt.figure(figsize=(8,6))
plt.imshow(matriz_correlacao,cmap='coolwarm',interpolation='nearest')
plt.colorbar()

# adicionando os valores de correlação nas células do gráfico
for i in range(len(df.columns)):
    for j in range(len(df.columns)):
        plt.text(i,j,f'{matriz_correlacao.iloc[i,j]:.2f}',ha='center',va='center',color='black',fontsize=12)

plt.xticks(np.arange(len(df.columns)),df.columns,rotation=45)
plt.yticks(np.arange(len(df.columns)),df.columns)
plt.title('Matriz de Correlação')
plt.show()

# %%
# Correlação de Spearman em Pandas e Matplotlib

import pandas as pd
import scipy.stats as stats

# criando um dataframe de exemplo com variáveis ordinais e contínuas
dados = {
    'Satisfação': ['Baixa','Média','Alta','Média','Alta'],
    'Idade': [25,30,35,40,45],
    'Salário': [50_000,60_000,75_000,90_000,100_000]
}

df = pd.DataFrame(dados)

# mapeando as categorias para valores ordinais
mapeamento_ordem = {'Baixa':1,'Média':2,'Alta':3}
df['Satisfação'] = df['Satisfação'].map(mapeamento_ordem)

# calculando a matriz de correlação de Spearman
matriz_correlacao_spearman = df.corr(method='spearman')

# imprimindo a matriz de correlação de spearman
print('Matriz de Correlação de Spearman:')
print(matriz_correlacao_spearman)

# outros valores para função method:
# spearman, pearson e kendall
# Out:
# Matriz de Correlação de Spearman:
#             Satisfação     Idade   Salário
# Satisfação    1.000000  0.737865  0.737865
# Idade         0.737865  1.000000  1.000000
# Salário       0.737865  1.000000  1.000000

# %% [markdown]
# ## Parte 2 - Estatística Descritiva: Medidas de Tendência Central e de Dispersão

# %% [markdown]
# * Medidas de tendência central

# %% [markdown]
# Relação entre as médias: MA >= MG >= MH
#
# Observação: o único caso em que MA = MG = MH é quando todos os elementos possuem o mesmo valor no conjunto de dados!

# %%
# média aritmética

# importando a função média
from statistics import mean
# dados
dados = [1,2,3,4,5]
# calculando a média aritmética
mean(dados)
# Out:
# 3

# %%
# média geométrica

# importando a função média geométrica
from scipy.stats.mstats import gmean
# dados
dados = [1,2,3,4,5]
# calculando a média geométrica
gmean(dados)
# Out:
# np.float64(2.6051710846973517)

# %%
# média harmônica

# importando a função média harmônica
from statistics import harmonic_mean
# dados
dados = [1,2,3,4,5]
# calculando a média harmônica
harmonic_mean(dados)
# Out:
# 2.18978102189781

# %%
# Mediana com n = ímpar

# importando a função mediana
from statistics import median
# dados
dados = [7,1,5,2,3,1,6]
# calculando a mediana
median(dados)
# Out:
# 3

# %%
# Mediana com n = par

# importando a função mediana
from statistics import median
# dados
dados = [1,2,1,1,4,5,3,6]
# calculando a mediana
median(dados)
# Out:
# 2.5

# %%
# moda - resultado unimodal

# importando a função moda
from statistics import mode
# dados 
dados = [4,5,4,6,5,8,4]
# calculando a moda
mode(dados)
# Out:
# 4

# %%
# moda - resultado bimodal

# importando a função moda
from statistics import multimode
# dados
dados = [4,5,4,6,5,8,4,4,5,5]
# calculando a moda
multimode(dados)
# Out:
# [4, 5]

# %%
# moda - resultado amodal

# importando a função moda
from statistics import multimode
# dados
dados = [1,2,3,4,5]
# calculando a moda
multimode(dados)
# Out:
# [1, 2, 3, 4, 5]

# %%
# medidas separatrizes - quartis e percentis
# Quartis dividem o conjunto em quatro partes iguais
# Q1 = 25% para baixo e 75% para cima
# Q2 = 50% = mediana, 50% para baixo e 50% para cima
# Q3 = 75% para baixo e 25% para cima
# Percentis dividem o conjunto em 100 partes iguais
# P25 = Q1
# P50 = Q2 = mediana
# P75 = Q3

# %%
# Exemplo: Calcule a mediana, primeiro e terceiro quartil das observações {3,1,5,2,3,1,7}

# importando bibliotecas
from statistics import median
import numpy as np
# dados
dados = [3,1,5,2,3,1,7]
# mediana
print(median(dados))
print(np.quantile(dados,0.25))
print(np.quantile(dados,0.75))
# Out:
# 3
# 1.5
# 4.0

# %% [markdown]
# Medidas de assimetria
# ![image.png](attachment:image.png)

# %%
# import
from scipy.stats import skew
# dados
x = [8.0,1,2.5,4,28.0]
# calculando assimetria - por padrão bias = True (populacional)
skew(x, bias=False) # bias = False, coeficiente de assimetria amostral não viesado
# Out:
# np.float64(1.9470432273905927)

# %% [markdown]
# * Medidas de dispersão

# %%
# Exemplo: Considere a amostra: {3,4,5,6,12}. Calcule: amplitude, variância, desvio padrão e coeficiente de variação da amostra.

# imports
from statistics import variance
from statistics import stdev
from statistics import mean
import numpy as np

# dados
dados = [3,4,5,6,12]

# Amplitude (manualmente, única opção)
print(np.max(dados) - np.min(dados))

# variância
print(variance(dados))

# desvio padrão
print(stdev(dados))

# coeficiente de variação (manual, única opção)
print(stdev(dados)/mean(dados)*100)
# Out:
# 9
# 12.5
# 3.5355339059327378
# 58.92556509887896

# %% [markdown]
# * Boxplot ou diagrama de caixas

# %%
# imports
import seaborn as sns
import matplotlib.pyplot as plt

# carregando dataset (iris) - o dataset da iris é nativo no python
dados = sns.load_dataset('iris')
# plotando um boxplot por species da característica petal length
sns.boxplot(x=dados['species'],y=dados['petal_length'])
plt.show()
